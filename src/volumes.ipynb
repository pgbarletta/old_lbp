# %% [markdown]
# # Calc de vol p/ una corrida

# %%
using DataFrames
using Chemfiles
using Gadfly
using Cairo
using Distributions
using Bio
using MIToS.PDB
set_default_plot_size(28cm, 10cm)

# %% [markdown]
# ## lfa_apo

# %%
lfa_apo_vol = readtable("/home/german/labo/16/lbp/run/lfa_apo/data/10_vol_lfa_apo", separator = ' ')
plot(lfa_apo_vol, x="Time", y="barrel", Geom.line)
# Out:
# Plot(...)

# %%
lfa_apo_vol = readtable("/home/german/labo/16/lbp/run/lfa_apo/data/50_vol_lfa_apo", separator = ' ')
plot(lfa_apo_vol, x="Time", y="barrel", Geom.line)
# Out:
# Plot(...)

# %%
lfa_apo_vol = readtable("/home/german/labo/16/lbp/run/lfa_apo/data/100_vol_lfa_apo", separator = ' ')
plot(lfa_apo_vol, x="Time", y="barrel", Geom.line)
# Out:
# Plot(...)

# %% [markdown]
# ## lfa_hol

# %%
lfa_hol_vol = readtable("/home/german/labo/16/lbp/run/lfa_hol/data/10_vol_lfa_hol", separator = ' ')
plot(lfa_hol_vol, x="Time", y="barrel", Geom.line)
# Out:
# Plot(...)

# %%
lfa_hol_vol = readtable("/home/german/labo/16/lbp/run/lfa_hol/data/50_vol_lfa_hol", separator = ' ')
plot(lfa_hol_vol, x="Time", y="barrel", Geom.line)
# Out:
# Plot(...)

# %%
lfa_hol_vol = readtable("/home/german/labo/16/lbp/run/lfa_hol/data/100_vol_lfa_hol", separator = ' ')
plot(lfa_hol_vol, x="Time", y="barrel", Geom.line)
# Out:
# Plot(...)

# %% [markdown]
# ## naf_apo

# %%
naf_apo_vol = readtable("/home/german/labo/16/lbp/run/naf_apo/data/10_vol_naf_apo", separator = ' ')
plot(naf_apo_vol, x="Time", y="barrel", Geom.line)

# %%
naf_apo_vol = readtable("/home/german/labo/16/lbp/run/naf_apo/data/50_vol_naf_apo", separator = ' ')
plot(naf_apo_vol, x="Time", y="barrel", Geom.line)

# %%
naf_apo_vol = readtable("/home/german/labo/16/lbp/run/naf_apo/data/100_vol_naf_apo", separator = ' ')
plot(naf_apo_vol, x="Time", y="barrel", Geom.line)

# %% [markdown]
# ## naf_hol

# %%
naf_hol_vol = readtable("/home/german/labo/16/lbp/run/naf_hol/data/10_vol_naf_hol", separator = ' ')
plot(naf_hol_vol, x="Time", y="barrel", Geom.line)

# %%
naf_hol_vol = readtable("/home/german/labo/16/lbp/run/naf_hol/data/50_vol_naf_hol", separator = ' ')
plot(naf_hol_vol, x="Time", y="barrel", Geom.line)

# %%
naf_hol_vol = readtable("/home/german/labo/16/lbp/run/naf_hol/data/100_vol_naf_hol", separator = ' ')
plot(naf_hol_vol, x="Time", y="barrel", Geom.line)
